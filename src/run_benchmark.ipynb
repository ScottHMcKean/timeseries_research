# %%
from dbtsr.main import get_spark

spark = get_spark()
spark.sql("SELECT 1.").show()
# Out:
# Running cells with '.venv (Python 3.11.11)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/scott.mckean/Repos/timeseries_research/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
